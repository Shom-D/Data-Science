# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data1 = np.array([0, 6])
data2 = np.array([0, 250])

plt.plot(data1, data2)
plt.show()

# %%
data1 = np.array([1,8])
data2 = np.array([3, 10])

plt.plot(data1, data2)
plt.show()

# %%
data1 = np.array([1,8])
data2 = np.array([3, 10])

plt.plot(data1, data2, "o")
plt.show()

# %%
data1 = np.array([1,2,6,8])
data2 = np.array([3, 8, 1, 10])
plt.plot(data1, data2, marker = "o")
plt.show()

# %%
data2 = np.array([3, 8, 1, 10])
plt.plot(data2, "*-.c")
plt.show()

# %%
data2 = np.array([3, 8, 1, 10])
plt.plot(data2, "-.c", lw = 2, marker = "o")
plt.show()

# %%
data2 = np.array([3, 8, 1, 10])
plt.plot(data2, "-.c", lw = 2, marker = "o", ms = 25, mec = "r", mfc = "k")
plt.show()

# %%
data2 = np.array([3, 8, 1, 10])
plt.plot(data2, "-.c", lw = 2, marker = "o", ms = 25, mfc = "#5FAF8EFF")
plt.show()
